# %% [markdown]
# ### Plot some samples with the pretrained models on the incomplete dataset

# %%
from multivae.data.datasets import MHD
from config import data_path

# %%
dataset = MHD(data_path, split='test')

# %%
from multivae.models import AutoModel
import os, glob
import json
from config import *
from multivae.metrics.reconstruction import Reconstruction, ReconstructionConfig
from multivae.metrics import Visualization, VisualizationConfig
import wandb
import matplotlib.pyplot as plt
import numpy as np

models_name = ['MMVAE','MVAE','MVTCAE','MoPoE','MMVAEPlus']
betas = ['beta_5']
rescales = ['True']

fig = plt.figure(figsize=(1.5*5,3.2*5))
i=1
for model_name in models_name:
    for beta in betas:
        for rescale in rescales:
  
            for seed in range(1):
            
                model_path = f'asenella/incomplete_mhd_{model_name}_{beta}_scale_{rescale}_seed_{seed}'
                model = AutoModel.load_from_hf_hub(model_path, allow_pickle=True)
                
               
                
                if seed==0:
                    vis_config = VisualizationConfig(
                        batch_size=128,
                        n_samples=3,
                        n_data_cond=4
                    )
                    
                    vis_module = Visualization(
                        model,
                        dataset,
                        # output=path,
                        eval_config=vis_config
                    )

                    
                    image = vis_module.conditional_samples_subset(['audio'], ['image', 'audio'])
                    
                    ax = plt.subplot(7,1,i)
                    

                    ax.imshow(np.array(image))
                    
                    ax.set_xticks([])
                    ax.set_yticks([])

                    
                    ax.set_ylabel(model_name)
                    
                    i+=1
                    
plt.tight_layout()

plt.savefig("recon_from_audio_incomplete")
# Out:
# Downloading config file ...
# Downloading MMVAE files for rebuilding...
# Successfully downloaded encoders architecture.
# Successfully downloaded decoders architecture.
# Successfully downloaded MMVAE model!
# Downloading config file ...
# Downloading (…)in/model_config.json: 100%|██████████| 421/421 [00:00<00:00, 189kB/s]
# Downloading MVAE files for rebuilding...
# Downloading (…)ain/environment.json: 100%|██████████| 55.0/55.0 [00:00<00:00, 29.0kB/s]
# Downloading model.pt: 100%|██████████| 81.3M/81.3M [00:02<00:00, 32.2MB/s]
# Downloading encoders.pkl: 100%|██████████| 49.4M/49.4M [00:01<00:00, 28.2MB/s]
# Successfully downloaded encoders architecture.
# Downloading decoders.pkl: 100%|██████████| 32.0M/32.0M [00:01<00:00, 24.2MB/s]
# Successfully downloaded decoders architecture.
# Successfully downloaded MVAE model!
# Downloading config file ...
# Downloading MVTCAE files for rebuilding...
# Successfully downloaded encoders architecture.
# Successfully downloaded decoders architecture.
# Successfully downloaded MVTCAE model!
# Downloading config file ...
# Downloading MoPoE files for rebuilding...
# Successfully downloaded encoders architecture.
# Successfully downloaded decoders architecture.
# Successfully downloaded MoPoE model!
# Downloading config file ...
# Downloading MMVAEPlus files for rebuilding...
# Successfully downloaded encoders architecture.
# Successfully downloaded decoders architecture.
# Successfully downloaded MMVAEPlus model!

# %%
from multivae.models import AutoModel
import os, glob
import json
from config import *
from multivae.metrics.reconstruction import Reconstruction, ReconstructionConfig
from multivae.metrics import Visualization, VisualizationConfig
import wandb
import matplotlib.pyplot as plt
import numpy as np

models_name = ['MMVAE','MVAE','MVTCAE','MoPoE','MMVAEPlus']
betas = ['beta_5']
rescales = ['True']

fig = plt.figure(figsize=(1.5*5,2.75*5))
i=1
for model_name in models_name:
    for beta in betas:
        for rescale in rescales:
  
            for seed in range(1):
                
                model_path = f'asenella/incomplete_mhd_{model_name}_{beta}_scale_{rescale}_seed_{seed}'
                model = AutoModel.load_from_hf_hub(model_path, allow_pickle=True)
                
                    
                
                if seed==0:
                    vis_config = VisualizationConfig(
                        batch_size=128,
                        n_samples=3,
                        n_data_cond=4
                    )
                    
                    vis_module = Visualization(
                        model,
                        dataset,
                        # output=path,
                        eval_config=vis_config
                    )

                    
                    image = vis_module.conditional_samples_subset(['trajectory'], ['image', 'audio'])
                    
                    ax = plt.subplot(7,1,i)
                    

                    ax.imshow(np.array(image))
                    
                    ax.set_xticks([])
                    ax.set_yticks([])

                    
                    ax.set_ylabel(model_name)
                    
                    i+=1
                    
plt.tight_layout()

plt.savefig("recon_from_trajectory_incomplete")
# Out:
# Downloading config file ...
# Downloading MMVAE files for rebuilding...
# Successfully downloaded encoders architecture.
# Successfully downloaded decoders architecture.
# Successfully downloaded MMVAE model!
# Downloading config file ...
# Downloading MVAE files for rebuilding...
# Successfully downloaded encoders architecture.
# Successfully downloaded decoders architecture.
# Successfully downloaded MVAE model!
# Downloading config file ...
# Downloading MVTCAE files for rebuilding...
# Successfully downloaded encoders architecture.
# Successfully downloaded decoders architecture.
# Successfully downloaded MVTCAE model!
# Downloading config file ...
# Downloading MoPoE files for rebuilding...
# Successfully downloaded encoders architecture.
# Successfully downloaded decoders architecture.
# Successfully downloaded MoPoE model!
# Downloading config file ...
# Downloading MMVAEPlus files for rebuilding...
# Successfully downloaded encoders architecture.
# Successfully downloaded decoders architecture.
# Successfully downloaded MMVAEPlus model!

# %%
from multivae.models import AutoModel
import os, glob
import json
from config import *
from multivae.metrics.reconstruction import Reconstruction, ReconstructionConfig
from multivae.metrics import Visualization, VisualizationConfig
import wandb
import matplotlib.pyplot as plt
import numpy as np

models_name = ['MMVAE','MVAE','MVTCAE','MoPoE','MMVAEPlus']
betas = ['beta_5']
rescales = ['True']

fig = plt.figure(figsize=(1.5*5,1*5))
i=1
for model_name in models_name:
    for beta in betas:
        for rescale in rescales:
  
            for seed in range(1):
                

                model_path = f'asenella/incomplete_mhd_{model_name}_{beta}_scale_{rescale}_seed_{seed}'
                model = AutoModel.load_from_hf_hub(model_path, allow_pickle=True)
                
               
                
                if seed==0:
                    vis_config = VisualizationConfig(
                        batch_size=128,
                        n_samples=3,
                        n_data_cond=4
                    )
                    
                    vis_module = Visualization(
                        model,
                        dataset,
                        # output=path,
                        eval_config=vis_config
                    )

                    
                    image = vis_module.conditional_samples_subset(['image'], ['image'])
                    
                    ax = plt.subplot(1,7,i)
                    

                    ax.imshow(np.array(image))
                    
                    ax.set_xticks([])
                    ax.set_yticks([])

                    
                    ax.set_title(model_name)
                    
                    i+=1
                    
plt.tight_layout()

plt.savefig("recon_image_incomplete")
# Out:
# Downloading config file ...
# Downloading MMVAE files for rebuilding...
# Successfully downloaded encoders architecture.
# Successfully downloaded decoders architecture.
# Successfully downloaded MMVAE model!
# Downloading config file ...
# Downloading MVAE files for rebuilding...
# Successfully downloaded encoders architecture.
# Successfully downloaded decoders architecture.
# Successfully downloaded MVAE model!
# Downloading config file ...
# Downloading MVTCAE files for rebuilding...
# Successfully downloaded encoders architecture.
# Successfully downloaded decoders architecture.
# Successfully downloaded MVTCAE model!
# Downloading config file ...
# Downloading MoPoE files for rebuilding...
# Successfully downloaded encoders architecture.
# Successfully downloaded decoders architecture.
# Successfully downloaded MoPoE model!
# Downloading config file ...
# Downloading MMVAEPlus files for rebuilding...
# Successfully downloaded encoders architecture.
# Successfully downloaded decoders architecture.
# Successfully downloaded MMVAEPlus model!
